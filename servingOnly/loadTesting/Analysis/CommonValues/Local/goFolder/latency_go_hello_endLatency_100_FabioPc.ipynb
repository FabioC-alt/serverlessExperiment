# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('latency_go_hello_endLatency_100_FabioPc.csv',sep=';',index_col=0)
df.drop(columns=['Unnamed: 3'], inplace=True)
cols = df.columns
print(cols)
df.head()
# Out:
# Index([' latency_ns', ' latency_ms'], dtype='object')
#            latency_ns  latency_ms
# iteration
# 1          1700448027    1700.448
# 2             2226133       2.226
# 3             2133048       2.133
# 4             1816861       1.817
# 5             2692724       2.693

# %%
median_values = df.median()
print(f"Median Value in ns: {median_values.iloc[0]}")
median_second = median_values.iloc[0]/1e9
print(f"Median Value in s: {median_second}")
# Out:
# Median Value in ns: 2248886.0
# Median Value in s: 0.002248886

# %%
# primo valore incide troppo, quindi:
df = df.drop(index=1)

df[' latency_ms'].plot(title='Latency in ms')
plt.xlabel('Iteration')
plt.ylabel('Latency (ms)')
plt.grid(True)
plt.show()
