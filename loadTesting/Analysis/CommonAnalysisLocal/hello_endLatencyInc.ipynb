# %%
import pandas as pd
import matplotlib.pyplot as plt
df_go = pd.read_csv('../goFolder/latency_go_hello_endLatencyInc_500_FabioPc.csv',sep=';',index_col=0)
df_java = pd.read_csv('../javaFolder/latency_javaQuarkus_hello_endLatencyInc_500_FabioPc.csv',sep=';',index_col=0)
df_node = pd.read_csv('../nodejsFolder/latency_js_hello_endLatencyInc_500_FabioPc.csv',sep=';',index_col=0)
df_go.drop(columns=['Unnamed: 3'], inplace=True)
df_java.drop(columns=['Unnamed: 3'], inplace=True)
df_node.drop(columns=['Unnamed: 3'], inplace=True)
cols = df_go.columns
print(cols)

df_go = df_go.drop(df_go.columns[0], axis=1)
df_go = df_go.drop(index=1)
df_go.head()
# Out:
# Index([' latency_ns', ' latency_ms'], dtype='object')
#            latency_ms
# iteration
# 2               2.571
# 3               2.337
# 4               2.358
# 5               2.455
# 6               1.583

# %%
df_java = df_java.drop(df_java.columns[0], axis=1)
df_java = df_java.drop(index=1)
df_java.head()
# Out:
#            latency_ms
# iteration
# 2               3.849
# 3               3.451
# 4               3.594
# 5               3.183
# 6               3.440

# %%
df_node = df_node.drop(df_node.columns[0], axis=1)
df_node = df_node.drop(index=1)
df_node.head()
# Out:
#            latency_ms
# iteration
# 2               2.188
# 3               2.400
# 4               2.256
# 5               2.701
# 6               2.973

# %%
plt.plot(df_go, label='go')
plt.plot(df_java, label='java')
plt.plot(df_node, label='node')
plt.xlabel('Iteration')
plt.ylabel('Latency (ms)')
plt.title("Latency")
plt.legend()
plt.show()
