# %%
import pandas as pd
df = pd.read_csv('latencies.txt', delimiter='\t')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['Values_ms'] = df['Values'] * 1000
print(df.head())
# Out:
#      Values  Values_ms
# 0  0.003735      3.735
# 1  0.001742      1.742
# 2  0.001816      1.816
# 3  0.002331      2.331
# 4  0.005202      5.202

# %%
plt.figure(figsize=(8, 3))
sns.violinplot(x='Values_ms', data=df, inner='box', color='skyblue')

plt.xlabel('Latency (ms)')
plt.title('Horizontal Violin Plot of Latency Values: 1 Node, RabbitMQ')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
