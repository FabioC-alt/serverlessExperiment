# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('latency_js_hello_endLatencyInc_500_FabioPc.csv',sep=';',index_col=0)
df.drop(columns=['Unnamed: 3'], inplace=True)
cols = df.columns
print(cols)
df.head()
# Out:
# Index([' latency_ns', ' latency_ms'], dtype='object')
#            latency_ns  latency_ms
# iteration
# 1            10121037      10.121
# 2             2187634       2.188
# 3             2400336       2.400
# 4             2256434       2.256
# 5             2701184       2.701

# %%
median_values = df.median()
print(f"Median Value in ns: {median_values.iloc[0]}")
median_second = median_values.iloc[0]/1e9
print(f"Median Value in s: {median_second}")
# Out:
# Median Value in ns: 2549938.5
# Median Value in s: 0.0025499385

# %%
df = df.drop(index=1)

df[' latency_ms'].plot(title='Latency in ms')
plt.xlabel('Iteration')
plt.ylabel('Latency (ms)')
plt.grid(True)
plt.show()
