# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('latency_js_hello_coldStart_50_FabioPc.csv',sep=';',index_col=0)
df.drop(columns=['Unnamed: 3'], inplace=True)
cols = df.columns
print(cols)
df.head()
# Out:
# Index([' latency_ns', ' latency_ms'], dtype='object')
#            latency_ns  latency_ms
# iteration
# 1            14431383      14.431
# 2          1190802444    1190.802
# 3          1179755347    1179.755
# 4          1202141810    1202.142
# 5          1173116297    1173.116

# %%
median_values = df.median()
print(f"Median Value in ns: {median_values.iloc[0]}")
median_second = median_values.iloc[0]/1e9
print(f"Median Value in s: {median_second}")
# Out:
# Median Value in ns: 1193483455.0
# Median Value in s: 1.193483455

# %%
df = df.drop(index=1)

df[' latency_ms'].plot(title='Latency in ms')
plt.xlabel('Iteration')
plt.ylabel('Latency (ms)')
plt.grid(True)
plt.show()
