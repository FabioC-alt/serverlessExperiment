# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('latency_go_minio_endLatencyInc_500_FabioPc.csv',sep=';',index_col=0)
df.drop(columns=['Unnamed: 3'], inplace=True)
cols = df.columns
print(cols)
df.head()
# Out:
# Index([' latency_ns', ' latency_ms'], dtype='object')
#            latency_ns  latency_ms
# iteration
# 1            30157170      30.157
# 2             7951731       7.952
# 3             8122083       8.122
# 4             8350966       8.351
# 5             7779586       7.780

# %%
median_values = df.median()
print(f"Median Value in ns: {median_values.iloc[0]}")
median_second = median_values.iloc[0]/1e9
print(f"Median Value in s: {median_second}")
# Out:
# Median Value in ns: 7578026.0
# Median Value in s: 0.007578026

# %%
df[' latency_ms'].plot(title='Latency in ms')
plt.xlabel('Iteration')
plt.ylabel('Latency (ms)')
plt.grid(True)
plt.show()
