# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('latency_javaQuarkus_hello_endLatencyInc_500_FabioPc.csv',sep=';',index_col=0)
df.drop(columns=['Unnamed: 3'], inplace=True)
cols = df.columns
print(cols)
df.head()
# Out:
# Index([' latency_ns', ' latency_ms'], dtype='object')
#            latency_ns  latency_ms
# iteration
# 1            10777556      10.778
# 2             3849450       3.849
# 3             3450918       3.451
# 4             3594348       3.594
# 5             3182972       3.183

# %%
median_values = df.median()
print(f"Median Value in ns: {median_values.iloc[0]}")
median_second = median_values.iloc[0]/1e9
print(f"Median Value in s: {median_second}")
# Out:
# Median Value in ns: 3269811.0
# Median Value in s: 0.003269811

# %%
df[' latency_ms'].plot(title='Latency in ms')
plt.xlabel('Iteration')
plt.ylabel('Latency (ms)')
plt.grid(True)
plt.show()
