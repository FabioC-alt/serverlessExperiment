# %%
import pandas as pd
import matplotlib.pyplot as plt
df_go = pd.read_csv('../goFolder/latency_go_minio_endLatencyInc_500_FabioPc.csv',sep=';',index_col=0)
df_java = pd.read_csv('../javaFolder/latency_javaQuarkus_minio_endLatencyInc_500_FabioPc.csv',sep=';',index_col=0)
df_node = pd.read_csv('../nodejsFolder/latency_js_minio_endLatencyInc_500_FabioPc.csv',sep=';',index_col=0)
df_go.drop(columns=['Unnamed: 3'], inplace=True)
df_java.drop(columns=['Unnamed: 3'], inplace=True)
df_node.drop(columns=['Unnamed: 3'], inplace=True)
cols = df_go.columns
print(cols)

df_go = df_go.drop(df_go.columns[0], axis=1)
df_go.head()
# Out:
# Index([' latency_ns', ' latency_ms'], dtype='object')
#            latency_ms
# iteration
# 1              30.157
# 2               7.952
# 3               8.122
# 4               8.351
# 5               7.780

# %%
df_java = df_java.drop(df_java.columns[0], axis=1)
df_java.head()
# Out:
#            latency_ms
# iteration
# 1              17.905
# 2               3.608
# 3               3.616
# 4               3.739
# 5               3.166

# %%
df_node = df_node.drop(df_node.columns[0], axis=1)
df_node.head()
# Out:
#            latency_ms
# iteration
# 1              19.515
# 2               3.853
# 3               3.643
# 4               4.310
# 5               4.363

# %%
plt.plot(df_go, label='go')
plt.plot(df_java, label='java')
plt.plot(df_node, label='node')
plt.xlabel('Iteration')
plt.ylabel('Latency (ms)')
plt.title("Latency")
plt.legend()
plt.show()
