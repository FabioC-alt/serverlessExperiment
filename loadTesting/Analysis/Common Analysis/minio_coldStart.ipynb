# %%
import pandas as pd
import matplotlib.pyplot as plt
df_go = pd.read_csv('../goFolder/latency_go_minio_coldStart_50_FabioPc.csv',sep=';',index_col=0)
df_java = pd.read_csv('../javaFolder/latency_javaQuarkus_minio_coldStart_50_FabioPc.csv',sep=';',index_col=0)
df_node = pd.read_csv('../nodejsFolder/latency_js_minio_coldStart_50_FabioPc.csv',sep=';',index_col=0)
df_go.drop(columns=['Unnamed: 3'], inplace=True)
df_java.drop(columns=['Unnamed: 3'], inplace=True)
df_node.drop(columns=['Unnamed: 3'], inplace=True)
cols = df_go.columns
print(cols)

df_go = df_go.drop(df_go.columns[0], axis=1)
df_go.head()
# Out:
# Index([' latency_ns', ' latency_ms'], dtype='object')
#            latency_ms
# iteration
# 1             243.604
# 2            1635.256
# 3            1218.470
# 4            1240.448
# 5            1228.511

# %%
df_java = df_java.drop(df_java.columns[0], axis=1)
df_java.head()
# Out:
#            latency_ms
# iteration
# 1            3704.076
# 2            2210.124
# 3            2214.359
# 4            2165.853
# 5            2214.820

# %%
df_node = df_node.drop(df_node.columns[0], axis=1)
df_node.head()
# Out:
#            latency_ms
# iteration
# 1            1686.691
# 2            1057.326
# 3            1030.436
# 4            1012.906
# 5            1190.569

# %%
plt.plot(df_go, label='go')
plt.plot(df_java, label='java')
plt.plot(df_node, label='node')
plt.xlabel('Iteration')
plt.ylabel('Latency (ms)')
plt.title("Latency: ColdStart, Minio")
plt.legend()
plt.show()
